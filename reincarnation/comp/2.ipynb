# %%
# %reload_ext reincarnation

# %% [markdown]
# # [Deathbeds](https://github.com/deathbeds)
#
# ## These are things we are doing.  They are readable through [nbviewer](https://nbviewer.jupyter.org/github/deathbeds/), reproducible on [Binder](https://mybinder.org) and in [Travis CI](https://travis-ci.org/deathbeds) ~~failing~~ ~~passing~~ ~~failing~~ tests, and reusable with `pip`, `conda` and `npm`.

# %%
"""digraph {rankdir=TB; subgraph clusterc{ label="literate computing"; data->"interactive computing" -> data -> "literate programming" ->data} {"interactive computing" "literate programming"} -> machines "literate programming" -> people {machines people} -> 🙉🙈🙊}"""

# %%
F"""- |
    At `deathbeds` we use notebooks daily to combine understand the act of the literate computing in the notebook.

- {interactive_rrr}"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-aea7fb04ccf1> in <module>()
#       1 F"""- |
#       2     At `deathbeds` we use notebooks daily to combine understand the act of the literate computing in the notebook.
# ----> 3 - {interactive_rrr}"""
#
# NameError: name 'interactive_rrr' is not defined

# %% [markdown]
# # Modern Inputs

# %% [markdown]
# * Forget the keyboard
# * ObservableHQ

# %% [markdown]
# ## Notebooks will be input
#
# If we agree to **restart and run all** and test our ideas then notebooks will useful for a long time.

# %% [markdown]
# ## Importing notebooks

# %% [markdown]
# # Input transformers

# %%
    ip = get_ipython()

# %%
    ip.input_splitter, ip.ast_transformers
# Out:
# (<IPython.core.inputsplitter.IPythonInputSplitter at 0x2c62cc346a0>,
#  [<deathbeds.2018-06-19-String-Node-Transformer.GraphViz at 0x2c62a5eb710>,
#   <deathbeds.2018-06-19-String-Node-Transformer.YamlDefinition at 0x2c62af65ba8>,
#   <deathbeds.2018-06-19-String-Node-Transformer.IframeDisplay at 0x2c62a626e10>,
#   <deathbeds.2018-08-16-HTML-Flexbox.FlexBoxTransformer at 0x2c62a132128>])

# %% [markdown]
# # Compute
#
# kernels, parameterization, testing,

# %% [markdown]
# Code as UI, the notebook is completely hackable.

# %% [markdown]
# # Outputs

# %% [markdown]
# [The Medium is the Message](https://en.wikipedia.org/wiki/The_medium_is_the_message)
#
# > For McLuhan, it was the medium itself that shaped and controlled "the scale and form of human association and action".
#
# ![](https://media.winnipegfreepress.com/images/648*389/2561532.jpg)

# %% [markdown]
# # Improving our **interaction** with our **machines** boosts **innovation** with **people**

# %% [markdown]
# # Readability 🤓
# All Machines
#
# # Reusability 👩‍💻 👨‍💻
# A Few Machines
#
# # Reproducibility 👩‍🚀👨‍🚀
# Many Machines

# %% [markdown]
# # Takeaways
#
# * Restart and run all
# * Write notebooks
