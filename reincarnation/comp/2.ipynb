# %% [markdown]
# # [2](2.ipynb)
#
# Notebooks can be a medium for computational essays that contain documentation and code.  deathbeds relies on notebooks that __restart and run all__.  As a consequence, our notebooks, or blog posts, are reusable as modules and tests.
#
# In our blog posts, we explore the ability to customize an author's conversation with the computer and other humans.

# %%
# %%capture
# %reload_ext reincarnation
from reincarnation.comp import __1

# %%
    IO = """digraph {rankdir=LR label=usage input -> compute -> output -> input}"""

# %% [markdown]
# # Mapping interactive computing to literacy

# %%
    F"""{__1.lit}"""
    F"""{__1.nb}"""
    F"""{IO}"""

# %% [markdown]
# # Experiments in inputs

# %% [markdown]
#     %%🎮
#     from deathbeds import __blacken_the_interactive_black_formatter_nbconvert

# %% [markdown]
#     %%🎮
#     %%blacken
#     print(                    "Seriously" \
#          "who would do " +
#          "this")

# %%
"""
- | 
    ### Code formatting is for computer programs.  Coding idioms are for computer programmers.
- http://www.cs.yale.edu/homes/perlis-alan/quotes.html"""
# Out:
# Row(content=['### Code formatting is for computer programs.  Coding idioms are for computer programmers.\n', 'http://www.cs.yale.edu/homes/perlis-alan/quotes.html'])

# %% [markdown]
# ## `get_ipython` allows us to modify how IPython works
#
# ... and you can too.

# %% [markdown]
#     %%🎮
#     from IPython import get_ipython
#     ip = get_ipython()

# %% [markdown]
#     %%🎮
#     ip.input_transformer_manager, ip.ast_transformers, ip.set_next_input

# %%
    """
    - http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-08-13-Flexbox-Transformer.ipynb
    - http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-08-04-Emojis-in-code-cells.ipynb
    """; """
    - http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-06-Markdown-code-cells.ipynb
    - http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-07-A-Jinja2-Templating-Transformer.md.ipynb"""
# Out:
# Row(content=['http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-08-13-Flexbox-Transformer.ipynb', 'http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-08-04-Emojis-in-code-cells.ipynb'])
# Row(content=['http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-06-Markdown-code-cells.ipynb', 'http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-07-A-Jinja2-Templating-Transformer.md.ipynb'])

# %%
    import deathbeds.__Markdown_code_cells

# %%
    # %reload_ext deathbeds.__Markdown_code_cells

# %% [markdown]
#     %%🎮
# # Markdown code cells
#
# What if code cells accepted markdown?  Then cells could be portable and literate.  Markdown mode would indicate off and Code mode would indicate on.
#
#     print(11)

# %%
    # %unload_ext deathbeds.__Markdown_code_cells
# Out:
#     %unload_ext deathbeds.__Markdown_code_cells

# %% [markdown]
# oh and we design our notebook modules to be magics.

# %% [markdown]
# # Compute

# %% [markdown]
# ## The first test is the hardest to write

# %%
    """http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-31-Testing-notebooks.ipynb"""
# Out:
#         <iframe
#             width="100%"
#             height="450"
#             src="http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-31-Testing-notebooks.ipynb"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# In this post you may learn that `doctest` is a readily available testing approach that may improve you code.

# %% [markdown]
#     %%🎮
#     __test__ = {
#         'this is a doctest': """>>> assert True"""
#     }
#     def this_function_has_a_doctest():
#         """>>> assert True"""
#
#     if __name__ == '__main__:
#         __import__('doctest').testmod(verbose=2);

# %% [markdown]
# or that `importnb` allows notebooks to be used as normal python modules in pytest.

# %%
"""http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-09-name-is-main.ipynb"""
# Out:
#         <iframe
#             width="100%"
#             height="450"
#             src="http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-09-name-is-main.ipynb"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
"""- |
    ## Interactive typing checking
- http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-06-20-Interactive-type-checking-with-datashape.ipynb"""
# Out:
# Row(content=['## Interactive typing checking\n', 'http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-06-20-Interactive-type-checking-with-datashape.ipynb'])

# %% [markdown]
#     %%🎮
#     from deathbeds import __interactive_type_checking_with_datashape
#     @__interactive_type_checking_with_datashape.typecheck
#     def f(x: "N * int") -> "N * string":
#         return list(map(str, x))
#     f([10])

# %% [markdown]
#     %%🎮
#     import numpy as np
#     __interactive_type_checking_with_datashape.matmul(np.random.randn(10,4), np.random.randn(3, 2))

# %% [markdown]
# ## Applying compute to analog ideas.

# %%
"""
- http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-06-23-Image-segmentation-on-flourishes.ipynb
- http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-10-Using-math-as-a-grid.ipynb"""
# Out:
# Row(content=['http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-06-23-Image-segmentation-on-flourishes.ipynb', 'http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-10-Using-math-as-a-grid.ipynb'])

# %% [markdown]
# # Outputs
#
# Widgets and alternative displays

# %%
    """- "Deathbeds hosts their work on nbv iewer and github"
            
    - http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/tree/master/deathbeds/
    """
# Out:
# Row(content=['Deathbeds hosts their work on nbv iewer and github', 'http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/tree/master/deathbeds/'])

# %%
    %%🎮
    from deathbeds import __poster_Geometry

    from deathbeds import __qr_codes_are_magic

    __poster_Geometry.CAD2.THREECAD()

    with capture() as code:
        __qr_codes_are_magic.qr("http://deathbeds.github.io -o svg")

# %%
"""http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-08-19-Github-issues-for-images.ipynb"""
# Out:
#         <iframe
#             width="100%"
#             height="450"
#             src="http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-08-19-Github-issues-for-images.ipynb"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
    %%🎮
    from deathbeds import __Github_issues_for_images
    __Github_issues_for_images._sample_issues_from_reincarnation()

# %% [markdown]
# ## Or what if our output displays were more interactive?

# %%
    """http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-13-Supercharged-imarkdown-as-code.md.ipynb"""
# Out:
#         <iframe
#             width="100%"
#             height="450"
#             src="http://nbviewer.jupyter.org/github/deathbeds/deathbeds.github.io/blob/master/deathbeds/2018-07-13-Supercharged-imarkdown-as-code.md.ipynb"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# [The Medium is the Message](https://en.wikipedia.org/wiki/The_medium_is_the_message)
#
# > For McLuhan, it was the medium itself that shaped and controlled "the scale and form of human association and action".
#
# ![](https://media.winnipegfreepress.com/images/648*389/2561532.jpg)

# %% [markdown]
# # [`deathbeds`](https://github.com/deathbeds)
#
# ## These are things we are doing.  They are readable through [nbviewer](https://nbviewer.jupyter.org/github/deathbeds/), reproducible on [Binder](https://mybinder.org) and in [Travis CI](https://travis-ci.org/deathbeds) ~~failing~~ ~~passing~~ ~~failing~~ tests, and reusable with `pip`, `conda` and `npm`.
#
# We attempt to use more modern inputs because the keyboard is engineered.
#
# We can write code for our future self and future friends.

# %% [markdown]
# # Improving our **interaction** with our **machines** boosts **innovation** with **people**

# %% [markdown]
# ## Restart and run all
# ## Write Notebooks
# ## Make Good Entropy
